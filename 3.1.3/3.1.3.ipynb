# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
t=np.array([
3.93,
3.28,
2.91,
2.52,
2.13])

n = np.array([
11,
9 ,
8 ,
7 ,
6])

# %%
plot_1 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $T(n)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$T$, с', fontsize=20, rotation=0, ha='right')
plt.xlabel('$n$, кол-во шариков', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 0.02 * t
#xerr_1 = 0.5



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    n,
    t,
    fmt='ko',
    linewidth=1,
    markersize=3,
    elinewidth=1,
    label='$T(n)$',
    #xerr=xerr_1,
    yerr=yerr_1,
    capsize=3
)



z = np.polyfit(n, t, deg=1)
polynom_1 = np.poly1d(z)
n = np.array([
11,
9 ,
8 ,
7 ,
6,
0])
plt.plot(n, polynom_1(n),"r--", linewidth=1, label="МНК")


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_1.savefig(
    'T(n).pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
#Mean squared error
x = n
y = t
n = len(n)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k_o, error_k, b
# Out:
# (0.36025641025641025, 0.007601276275907047, -0.002432432432433629)

# %%
n_1 = np.array([
12,
10,
8 ,
6 ,
4])

mom = np.array([
418,
314,
209,
191,
150])

# %%
plot_2 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $M(n)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$M$, мкН$\cdot$м', fontsize=20, rotation=0, ha='right')
plt.xlabel('$n$, кол-во шариков', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 0.05 * mom
#xerr_1 = 0.5



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    n_1,
    mom,
    fmt='ko',
    linewidth=1,
    markersize=3,
    elinewidth=1,
    label='$M(n)$',
    #xerr=xerr_1,
    yerr=yerr_1,
    capsize=3
)



z = np.polyfit(n_1, mom, deg=1)
polynom_1 = np.poly1d(z)
n_2 = np.array([
12,
10,
8 ,
6 ,
4,
0])
plt.plot(n_2, polynom_1(n_2),"r--", linewidth=1, label="МНК")


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_2.savefig(
    'M(n).pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
#Mean squared error
x = n_1
y = mom
n = len(n_1)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (32.950000000000045, 4.386969341128274, -7.2000000000003865)
