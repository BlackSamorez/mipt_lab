# %%
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

plt.savefig('1.pgf')
plt.show()

matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

x_1 = [0.1, 3.46, 4.66, 10.26, 13.55, 16.4, 18.7, 19.2, 20, 21.1,  22.07, 22.4,   22.51, 22.86, 23.66, 27.2, 28.88, 31.57, 35.97, 36.89, 37.94, 40.35, 43.40, 42.64, 46.93]
y_1 = [2, 10, 14, 33, 43, 51, 56, 57, 57, 57.5,  56, 55,   53.5, 47, 42, 55, 62, 72, 86, 86, 87, 83, 81, 81, 83.5  ]

z_1 = np.polyfit(x_1, y_1, 17)

x_2 = [0.1, 4.27, 8.41, 12.26, 16.64, 19.23, 20.17, 20.98, 22.57, 23.53, 24.34, 25.35, 26.9, 33.44, 37.42, 37.95, 39.63, 41.79, 44.34, 46.69, 49.5, 61.3]
y_2 = [0, 8, 21, 35, 48, 54, 55, 55, 53, 31, 29, 29.5, 36, 64, 73.5, 74, 72, 68, 64, 63, 66, 83]

x_3 = [4.17, 9.85, 15.87, 18.63, 19.53, 20.10, 20.78, 22.00, 24.28, 25.15, 28.78, 32.07, 37.64, 38.62, 39.9, 44.33, 47.57, 48.84, 51.15, 54.42]
y_3 = [3, 20.5, 40, 48, 50, 51, 51.5, 51, 22, 19, 27, 43, 59, 60, 58 , 51 , 42, 41.5, 48.5, 53.5]
# Out:
# /home/orventro/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# sns.set(style="whitegrid", font_scale=1.4)

plt.figure(figsize=(6, 4))
plt.plot(x_1, y_1, label='U = 4V')
plt.plot(x_2, y_2, label='U = 6V')
plt.plot(x_3, y_3, label='U = 8V')
plt.scatter(x=x_1, y=y_1, marker='.')
plt.scatter(x=x_2, y=y_2, marker='.')
plt.scatter(x=x_3, y=y_3, marker='.')
plt.legend(loc='best')
plt.xlabel("V, B", fontsize=10)
plt.ylabel("I, $\mu$", fontsize=10)
plt.grid(linestyle='--')
plt.savefig('plot.pgf')
plt.show()
# Out:
# /tmp/ipykernel_15590/207172362.py:15: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
z_2 = np.polyfit(x_2, y_2, 9)
p = np.poly1d(z_2)

# %%
xp = np.linspace(0, 62, 100)
_ = plt.plot(x_2, y_2, '.', xp, p(xp), '-')
plt.ylim(0,90)

plt.show()
# Out:
# /tmp/ipykernel_15254/1760173064.py:5: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
