# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
L_3kgz = np.array([
4  ,
62 ,
119,
177])
k_3kgz = np.linspace(1, len(L_3kgz), len(L_3kgz))

L_4kgz = np.array([
34 ,
77 ,
121,
162,
207])
k_4kgz = np.linspace(1, len(L_4kgz), len(L_4kgz))

L_5kgz = np.array([
16 ,
52 ,
86 ,
122,
156,
191])
k_5kgz = np.linspace(1, len(L_5kgz), len(L_5kgz))

L_6kgz = np.array([
6 , 
36 ,
65 ,
94 ,
123,
151])
k_6kgz = np.linspace(1, len(L_6kgz), len(L_6kgz))

# %%
plot_1 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $\Delta L(k)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$\Delta L$, мм', fontsize=20, rotation=0, ha='right')
plt.xlabel('$k$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 1
xerr_1 = 2



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    k_3kgz,
    L_3kgz,
    fmt='ko',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='3 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k_4kgz,
    L_4kgz,
    fmt='ro',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='4 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k_5kgz,
    L_5kgz,
    fmt='bo',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='5 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k_6kgz,
    L_6kgz,
    fmt='yo',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='6 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

z_1 = np.polyfit(k_3kgz, L_3kgz, deg=1)
polynom_1 = np.poly1d(z_1)
plt.plot(k_6kgz, polynom_1(k_6kgz),"k--", linewidth=1)

z_2 = np.polyfit(k_4kgz, L_4kgz, deg=1)
polynom_2 = np.poly1d(z_2)
plt.plot(k_6kgz, polynom_2(k_6kgz),"r--", linewidth=1)

z_3 = np.polyfit(k_5kgz, L_5kgz, deg=1)
polynom_3 = np.poly1d(z_3)
plt.plot(k_6kgz, polynom_3(k_6kgz),"b--", linewidth=1)

z_4 = np.polyfit(k_6kgz, L_6kgz, deg=1)
polynom_4 = np.poly1d(z_4)
plt.plot(k_6kgz, polynom_4(k_6kgz),"y--", linewidth=1)


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_1.savefig(
    'L(k).pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
#Mean squared error
x = k_6kgz
y = L_6kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (29.0, 0.1126872339636549, -22.33333333333333)

# %%
#Mean squared error
x = k_5kgz
y = L_5kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (34.94285714285716, 0.11024606574079865, -18.466666666666725)

# %%
#Mean squared error
x = k_4kgz
y = L_4kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (43.099999999999994, 0.2121320343558678, -9.09999999999998)

# %%
#Mean squared error
x = k_3kgz
y = L_3kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (57.6, 0.08164965809273549, -53.5)

# %%
L_3kgz = np.array([
8  ,
61 ,
113,
174])
k_3kgz = np.linspace(1, len(L_3kgz), len(L_3kgz))

L_4kgz = np.array([
7  ,
43 ,
80 ,
116,
154,
195])
k_4kgz = np.linspace(1, len(L_4kgz), len(L_4kgz))

L_5kgz = np.array([
30 ,
57 ,
92 ,
115,
141,
172])
k_5kgz = np.linspace(1, len(L_5kgz), len(L_5kgz))

# %%
plot_2 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $\Delta L(k)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$\Delta L$, мм', fontsize=20, rotation=0, ha='right')
plt.xlabel('$k$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 1
xerr_1 = 2



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    k_3kgz,
    L_3kgz,
    fmt='ko',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='3 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k_4kgz,
    L_4kgz,
    fmt='ro',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='4 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k_5kgz,
    L_5kgz,
    fmt='bo',
    linewidth=0,
    markersize=8,
    elinewidth=1,
    label='5 kHz',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)


z_1 = np.polyfit(k_3kgz, L_3kgz, deg=1)
polynom_1 = np.poly1d(z_1)
plt.plot(k_6kgz, polynom_1(k_6kgz),"k--", linewidth=1)

z_2 = np.polyfit(k_4kgz, L_4kgz, deg=1)
polynom_2 = np.poly1d(z_2)
plt.plot(k_6kgz, polynom_2(k_6kgz),"r--", linewidth=1)

z_3 = np.polyfit(k_5kgz, L_5kgz, deg=1)
polynom_3 = np.poly1d(z_3)
plt.plot(k_6kgz, polynom_3(k_6kgz),"b--", linewidth=1)


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_2.savefig(
    'CO.pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
#Mean squared error
x = k_5kgz
y = L_5kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (28.142857142857142, 0.5730136745329906, 2.6666666666666714)

# %%
#Mean squared error
x = k_4kgz
y = L_4kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (37.4, 0.3454925170898796, -31.733333333333334)

# %%
#Mean squared error
x = k_3kgz
y = L_3kgz
n = len(k_6kgz)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (55.0, 0.8366600265340576, -48.5)

# %%
der_air = np.array([
29,
34.94285714285716,
43.09999999999999,
57.6])
der_hz_air = np.linspace(3, 6, 4)

der_co = np.array([
28.142857142857142,
37.4,
55.0])
der_hz_co = np.linspace(3, 5, 3)

# %%
plot_3 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $c(f)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$c$, м$/$с', fontsize=20, rotation=0, ha='right')
plt.xlabel('$f$, кГц', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 1
xerr_1 = 2



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    der_hz_air,
    der_air[::-1]*der_hz_air*2,
    fmt='ko',
    linewidth=0,
    markersize=14,
    elinewidth=1,
    label='Воздух',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    der_hz_co,
    der_hz_co*der_co[::-1]*2,
    fmt='ro',
    linewidth=0,
    markersize=14,
    elinewidth=1,
    label='$CO_2$',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_3.savefig(
    'c(f).pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
k = np.linspace(1,9,9)
nu_23 = np.array([
264 ,
498 ,
741 ,
989 ,
1235,
1480,
1727,
1976,
2218])
nu_35 = np.array([
263 ,
507 ,
755 ,
1009,
1259,
1509,
1753,
2013,
2260])
nu_50 = np.array([
275 ,
519 ,
773 ,
1031,
1288,
1543,
1799,
2061,
2312])
dnu_23 = nu_23 - nu_23[0]
dnu_35 = nu_35 - nu_35[0]
dnu_50= nu_50 - nu_50[0]

# %%
plot_4 = plt.figure(figsize=(12*0.9,10*0.9))
plt.grid(visible=True, linewidth=0.6)

plt.title('Зависимость $f_{k+1} - f_1(k)$', fontsize=18)
#plt.xlim(xmin=0, xmax=0.03)
#plt.ylim(ymin=0, ymax=100)
plt.ylabel('$f_{k+1} - f_1$, Гц', fontsize=20, rotation=0, ha='right')
plt.xlabel('$k$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16, size=10)
plt.grid(visible=True, linewidth=0.6)



yerr_1 = 1
xerr_1 = 2



#z, err = np.polyfit(D, Q[1], deg=1, cov=True)
#polynom_2 = np.poly1d(z)
#plt.plot(D, polynom_2(D),"b--", linewidth=1, label="МНК")

plt.errorbar(
    k,
    dnu_23,
    fmt='ko',
    linewidth=0,
    markersize=3,
    elinewidth=1,
    label='23$^\circ C$',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k,
    dnu_35,
    fmt='ro',
    linewidth=0,
    markersize=3,
    elinewidth=1,
    label='35$^\circ C$',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)

plt.errorbar(
    k,
    dnu_50,
    fmt='bo',
    linewidth=0,
    markersize=3,
    elinewidth=1,
    label='50$^\circ C$',
    #xerr=xerr_1,
    #yerr=yerr_1,
    capsize=3
)


z_1 = np.polyfit(k, dnu_23, deg=1)
polynom_1 = np.poly1d(z_1)
plt.plot(k, polynom_1(k),"k--", linewidth=1)

z_2 = np.polyfit(k, dnu_35, deg=1)
polynom_2 = np.poly1d(z_2)
plt.plot(k, polynom_2(k),"r--", linewidth=1)

z_3 = np.polyfit(k, dnu_50, deg=1)
polynom_3 = np.poly1d(z_3)
plt.plot(k, polynom_3(k),"b--", linewidth=1)


plt.legend(fontsize=18, markerscale = 1)
plt.show()

plot_4.savefig(
    'nu(k).pdf',
    format='pdf',
    bbox_inches='tight',
    #pad_inches=4
)

# %%
#Mean squared error
x = k
y = dnu_23
n = len(k)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (245.21666666666655, 0.4895303031451499, -253.63888888888835)

# %%
#Mean squared error
x = k
y = dnu_50
n = len(k)
k = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x * x) - np.mean(x) ** 2)
b = np.mean(y) - k * np.mean(x)
k_o = np.mean(x*y) / np.mean(x ** 2)
error_k = 1 / np.sqrt(n) * np.sqrt(((np.mean(y * y)) - np.mean(y) ** 2) / (np.mean(x * x) - np.mean(x) ** 2) - k**2)
k, error_k, b
# Out:
# (255.63333333333335, 0.5126787553324763, -264.16666666666674)
